# %%
# %matplotlib inline

# %%
from openAddressing import DoubleProbingHashST

# %% [markdown]
# ## Experiment: Insert words of "Tale Of Two Cities" into a Double Hash Open Addressing Hash Table

# %% [markdown]
# ### Initial table size = 11

# %%
d = DoubleProbingHashST(M=11)
with open("TaleOfTwoCities.txt", mode='r', encoding='utf-8') as f:
    for line in f:
        words = (word for word in line.split() if len(word) > 7)
        for w in words:
            if d.get(w):
                d.put(w, d.get(w) + 1)
            else:
                d.put(w, 1)
d.a.plotData(xlim=50, ylim=12)

# %%
print("final table size:", d.M)
# Out:
# final table size: 16381

# %%
print("number of keys: ", d.N)
# Out:
# number of keys:  4371

# %%
d.a.plotData()

# %% [markdown]
# ### Initial table size = 61

# %%
d = DoubleProbingHashST(M=61)
with open("TaleOfTwoCities.txt", mode='r', encoding='utf-8') as f:
    for line in f:
        words = (word for word in line.split() if len(word) > 7)
        for w in words:
            if d.get(w):
                d.put(w, d.get(w) + 1)
            else:
                d.put(w, 1)
d.a.plotData(xlim=50, ylim=5)

# %%
print("final table size:", d.M)
# Out:
# final table size: 16381

# %%
d = DoubleProbingHashST(M=61)
with open("TaleOfTwoCities.txt", mode='r', encoding='utf-8') as f:
    for line in f:
        words = (word for word in line.split() if len(word) > 7)
        for w in words:
            if d.get(w):
                d.put(w, d.get(w) + 1)
            else:
                d.put(w, 1)
d.a.plotData()

# %%
d.a.means[13524]
# Out:
# 3.3468391866913123
